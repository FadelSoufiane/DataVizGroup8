# %%
import pandas as pd
temp = pd.read_csv("DataTemp.csv")

temp.head()
a = temp["dt"]
type(a)
r = a.str.findall("12-01")
r
# Out:
# pandas.core.series.Series

# %%
cities = temp.filter(like='Abidjan', axis=0)
temp.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0  1849-01-01              26.704                          1.435  Abidjan
# 1  1849-02-01              27.434                          1.362  Abidjan
# 2  1849-03-01              28.101                          1.612  Abidjan
# 3  1849-04-01              26.140                          1.387  Abidjan
# 4  1849-05-01              25.427                          1.200  Abidjan
#
#          Country Latitude Longitude
# 0  Côte D'Ivoire    5.63N     3.23W
# 1  Côte D'Ivoire    5.63N     3.23W
# 2  Côte D'Ivoire    5.63N     3.23W
# 3  Côte D'Ivoire    5.63N     3.23W
# 4  Côte D'Ivoire    5.63N     3.23W

# %%
#temp1
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
temp1_moy = temp1.groupby("City")
temp1_moy
# Out:
#                   AverageTemperature  AverageTemperatureUncertainty
# City
# Abidjan                    27.017583                       0.290167
# Addis Abeba                18.606750                       0.895583
# Ahmadabad                  27.290417                       0.419083
# Aleppo                     18.016583                       0.440250
# Alexandria                 21.181500                       0.303083
# Ankara                     10.389667                       0.328917
# Baghdad                    23.437500                       0.274417
# Bangalore                  25.362083                       0.332417
# Bangkok                    27.558333                       0.360167
# Belo Horizonte             21.740500                       0.354500
# Berlin                     10.556417                       0.266583
# Bogotá                     20.544250                       0.422750
# Bombay                     27.384917                       0.339583
# Brasília                   22.387167                       0.360667
# Cairo                      21.986917                       0.296917
# Calcutta                   26.406917                       0.327500
# Cali                       22.330000                       0.398417
# Cape Town                  16.621083                       0.526917
# Casablanca                 18.533083                       0.600250
# Changchun                   5.758667                       0.421000
# Chengdu                    11.074333                       0.468583
# Chicago                    11.214250                       0.401750
# Chongqing                  17.382917                       0.298333
# Dakar                      25.411000                       0.539750
# Dalian                     10.913583                       0.353500
# Dar Es Salaam              26.557917                       0.318083
# Delhi                      25.629500                       0.427250
# Dhaka                      25.803250                       0.385583
# Durban                     20.722333                       0.471250
# Faisalabad                 24.975250                       0.353917
# ...                              ...                            ...
# New Delhi                  25.629500                       0.427250
# New York                   11.272250                       0.296750
# Paris                      12.325750                       0.246583
# Peking                     12.770250                       0.416667
# Pune                       25.161417                       0.298750
# Rangoon                    27.203250                       0.393667
# Rio De Janeiro             24.319833                       0.375083
# Riyadh                     26.396750                       0.506250
# Rome                       13.463167                       0.406917
# Saint Petersburg            6.056250                       0.301250
# Salvador                   25.283667                       0.484250
# Santiago                    6.268583                       0.376083
# Santo Domingo              26.663500                       0.331000
# Seoul                      11.122417                       0.309333
# Shanghai                   16.518000                       0.248917
# Shenyang                    8.043833                       0.309583
# Singapore                  27.282167                       0.274083
# Surabaya                   27.190250                       0.282750
# Surat                      27.016583                       0.319500
# Sydney                     17.713333                       0.206750
# São Paulo                  20.330083                       0.343167
# Taipei                     22.551833                       0.263333
# Taiyuan                     8.643167                       0.305167
# Tangshan                   12.258833                       0.319250
# Tianjin                    12.770250                       0.416667
# Tokyo                      13.321833                       0.229833
# Toronto                     7.299583                       0.281417
# Umm Durman                 29.963667                       0.896000
# Wuhan                      17.387583                       0.315417
# Xian                       12.075167                       0.390583
#
# [100 rows x 2 columns]

# %%
type(temp1["City"])
c = temp1["City"]
cval = c.values
countries = pd.unique(cval)
len(countries)
temp1_moy["City"] = countries

#deplac = temp1_moy.iloc[0,2]
#temp1_moy.iloc[0,2] = temp1_moy.iloc[-1,2]
#temp1_moy.iloc[-1,2] = deplac
temp1_moy
# Out:
#                   AverageTemperature  AverageTemperatureUncertainty  \
# City
# Abidjan                    27.017583                       0.290167
# Addis Abeba                18.606750                       0.895583
# Ahmadabad                  27.290417                       0.419083
# Aleppo                     18.016583                       0.440250
# Alexandria                 21.181500                       0.303083
# Ankara                     10.389667                       0.328917
# Baghdad                    23.437500                       0.274417
# Bangalore                  25.362083                       0.332417
# Bangkok                    27.558333                       0.360167
# Belo Horizonte             21.740500                       0.354500
# Berlin                     10.556417                       0.266583
# Bogotá                     20.544250                       0.422750
# Bombay                     27.384917                       0.339583
# Brasília                   22.387167                       0.360667
# Cairo                      21.986917                       0.296917
# Calcutta                   26.406917                       0.327500
# Cali                       22.330000                       0.398417
# Cape Town                  16.621083                       0.526917
# Casablanca                 18.533083                       0.600250
# Changchun                   5.758667                       0.421000
# Chengdu                    11.074333                       0.468583
# Chicago                    11.214250                       0.401750
# Chongqing                  17.382917                       0.298333
# Dakar                      25.411000                       0.539750
# Dalian                     10.913583                       0.353500
# Dar Es Salaam              26.557917                       0.318083
# Delhi                      25.629500                       0.427250
# Dhaka                      25.803250                       0.385583
# Durban                     20.722333                       0.471250
# Faisalabad                 24.975250                       0.353917
# ...                              ...                            ...
# New Delhi                  25.629500                       0.427250
# New York                   11.272250                       0.296750
# Paris                      12.325750                       0.246583
# Peking                     12.770250                       0.416667
# Pune                       25.161417                       0.298750
# Rangoon                    27.203250                       0.393667
# Rio De Janeiro             24.319833                       0.375083
# Riyadh                     26.396750                       0.506250
# Rome                       13.463167                       0.406917
# Saint Petersburg            6.056250                       0.301250
# Salvador                   25.283667                       0.484250
# Santiago                    6.268583                       0.376083
# Santo Domingo              26.663500                       0.331000
# Seoul                      11.122417                       0.309333
# Shanghai                   16.518000                       0.248917
# Shenyang                    8.043833                       0.309583
# Singapore                  27.282167                       0.274083
# Surabaya                   27.190250                       0.282750
# Surat                      27.016583                       0.319500
# Sydney                     17.713333                       0.206750
# São Paulo                  20.330083                       0.343167
# Taipei                     22.551833                       0.263333
# Taiyuan                     8.643167                       0.305167
# Tangshan                   12.258833                       0.319250
# Tianjin                    12.770250                       0.416667
# Tokyo                      13.321833                       0.229833
# Toronto                     7.299583                       0.281417
# Umm Durman                 29.963667                       0.896000
# Wuhan                      17.387583                       0.315417
# Xian                       12.075167                       0.390583
#
#                               City
# City
# Abidjan                    Abidjan
# Addis Abeba            Addis Abeba
# Ahmadabad                Ahmadabad
# Aleppo                      Aleppo
# Alexandria              Alexandria
# Ankara                      Ankara
# Baghdad                    Baghdad
# Bangalore                Bangalore
# Bangkok                    Bangkok
# Belo Horizonte      Belo Horizonte
# Berlin                      Berlin
# Bogotá                      Bogotá
# Bombay                      Bombay
# Brasília                  Brasília
# Cairo                        Cairo
# Calcutta                  Calcutta
# Cali                          Cali
# Cape Town                Cape Town
# Casablanca              Casablanca
# Changchun                Changchun
# Chengdu                    Chengdu
# Chicago                    Chicago
# Chongqing                Chongqing
# Dakar                        Dakar
# Dalian                      Dalian
# Dar Es Salaam        Dar Es Salaam
# Delhi                        Delhi
# Dhaka                        Dhaka
# Durban                      Durban
# Faisalabad              Faisalabad
# ...                            ...
# New Delhi                New Delhi
# New York                  New York
# Paris                        Paris
# Peking                      Peking
# Pune                          Pune
# Rangoon                    Rangoon
# Rio De Janeiro      Rio De Janeiro
# Riyadh                      Riyadh
# Rome                          Rome
# Saint Petersburg         São Paulo
# Salvador          Saint Petersburg
# Santiago                  Salvador
# Santo Domingo             Santiago
# Seoul                Santo Domingo
# Shanghai                     Seoul
# Shenyang                  Shanghai
# Singapore                 Shenyang
# Surabaya                 Singapore
# Surat                     Surabaya
# Sydney                       Surat
# São Paulo                   Sydney
# Taipei                      Taipei
# Taiyuan                    Taiyuan
# Tangshan                  Tangshan
# Tianjin                    Tianjin
# Tokyo                        Tokyo
# Toronto                    Toronto
# Umm Durman              Umm Durman
# Wuhan                        Wuhan
# Xian                          Xian
#
# [100 rows x 3 columns]

# %%
temp1_moy = temp1_moy.drop(["AverageTemperatureUncertainty"],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-9b18b202838e> in <module>
# ----> 1 temp1_moy = temp1_moy.drop(["AverageTemperatureUncertainty"],axis=1)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['AverageTemperatureUncertainty'] not found in axis"

# %%
temp1_moy.to_csv('2012 cities.csv', index=False)

# %%
temp2 = temp[(temp["dt"] >=  "1844-01-01")]
temp2 = temp2[(temp2["dt"] <  "1945-01-01")]
temp2_moy = temp2.groupby("Country").mean()
c = temp2["Country"]
cval = c.values
countries = pd.unique(cval)
len(countries)
temp2_moy["country"] = countries
temp2_moy = temp2_moy.drop(["AverageTemperatureUncertainty"],axis=1)
temp2_moy.to_csv('1844-1945.csv', index=False)
temp2_moy
# Out:
#                                    AverageTemperature  \
# Country
# Afghanistan                                 13.718510
# Africa                                      23.814479
# Albania                                     12.484180
# Algeria                                     22.810849
# American Samoa                              26.296995
# Andorra                                     11.013523
# Angola                                      21.537013
# Anguilla                                    26.327997
# Antigua And Barbuda                         26.154864
# Argentina                                   14.330684
# Armenia                                      8.379282
# Aruba                                       27.646786
# Asia                                         7.108617
# Australia                                   21.413293
# Austria                                      5.992630
# Azerbaijan                                  10.982427
# Bahamas                                     24.923630
# Bahrain                                     25.623424
# Baker Island                                25.061746
# Bangladesh                                  24.677817
# Barbados                                    26.170163
# Belarus                                      5.606575
# Belgium                                      9.314773
# Belize                                      24.824923
# Benin                                       26.900261
# Bhutan                                      11.649331
# Bolivia                                     20.619194
# Bonaire, Saint Eustatius And Saba           26.895592
# Bosnia And Herzegovina                      10.235292
# Botswana                                    21.589572
# ...                                               ...
# Sweden                                       2.248858
# Switzerland                                  6.773068
# Syria                                       17.804059
# Taiwan                                      21.644645
# Tajikistan                                   3.715019
# Tanzania                                    22.094053
# Thailand                                    25.780543
# Timor Leste                                 25.675151
# Togo                                        26.591110
# Tonga                                       22.901019
# Trinidad And Tobago                         25.826078
# Tunisia                                     19.800469
# Turkey                                      11.515206
# Turkmenistan                                14.498376
# Turks And Caicas Islands                    26.440433
# Uganda                                      22.784684
# Ukraine                                      7.466603
# United Arab Emirates                        27.369710
# United Kingdom                               8.399121
# United Kingdom (Europe)                      8.569718
# United States                                8.516126
# Uruguay                                     16.917343
# Uzbekistan                                  11.988076
# Venezuela                                   24.736840
# Vietnam                                     23.431112
# Virgin Islands                              26.052433
# Western Sahara                              22.160456
# Yemen                                       25.969142
# Zambia                                      21.006801
# Zimbabwe                                    20.828092
#
#                                                              country
# Country
# Afghanistan                                              Afghanistan
# Africa                                                        Africa
# Albania                                                      Albania
# Algeria                                                      Algeria
# American Samoa                                        American Samoa
# Andorra                                                      Andorra
# Angola                                                        Angola
# Anguilla                                                    Anguilla
# Antigua And Barbuda                              Antigua And Barbuda
# Argentina                                                  Argentina
# Armenia                                                      Armenia
# Aruba                                                          Aruba
# Asia                                                            Asia
# Australia                                                  Australia
# Austria                                                      Austria
# Azerbaijan                                                Azerbaijan
# Bahamas                                                      Bahamas
# Bahrain                                                      Bahrain
# Baker Island                                            Baker Island
# Bangladesh                                                Bangladesh
# Barbados                                                    Barbados
# Belarus                                                      Belarus
# Belgium                                                      Belgium
# Belize                                                        Belize
# Benin                                                          Benin
# Bhutan                                                        Bhutan
# Bolivia                                                      Bolivia
# Bonaire, Saint Eustatius And Saba  Bonaire, Saint Eustatius And Saba
# Bosnia And Herzegovina                        Bosnia And Herzegovina
# Botswana                                                    Botswana
# ...                                                              ...
# Sweden                                                        Sweden
# Switzerland                                              Switzerland
# Syria                                                          Syria
# Taiwan                                                        Taiwan
# Tajikistan                                                Tajikistan
# Tanzania                                                    Tanzania
# Thailand                                                    Thailand
# Timor Leste                                              Timor Leste
# Togo                                                            Togo
# Tonga                                                          Tonga
# Trinidad And Tobago                              Trinidad And Tobago
# Tunisia                                                      Tunisia
# Turkey                                                        Turkey
# Turkmenistan                                            Turkmenistan
# Turks And Caicas Islands                    Turks And Caicas Islands
# Uganda                                                        Uganda
# Ukraine                                                      Ukraine
# United Arab Emirates                            United Arab Emirates
# United Kingdom                               United Kingdom (Europe)
# United Kingdom (Europe)                               United Kingdom
# United States                                          United States
# Uruguay                                                      Uruguay
# Uzbekistan                                                Uzbekistan
# Venezuela                                                  Venezuela
# Vietnam                                                      Vietnam
# Virgin Islands                                        Virgin Islands
# Western Sahara                                        Western Sahara
# Yemen                                                          Yemen
# Zambia                                                        Zambia
# Zimbabwe                                                    Zimbabwe
#
# [239 rows x 2 columns]

# %%
temperature = temp[(temp["dt"] >=  "2013-01-01")]
temperature = temperature[(temperature["dt"] <=  "2013-12-31")]
temperature_moy = temperature.groupby("Country").mean()
c = temperature["Country"]
cval = c.values
countries = pd.unique(cval)
len(countries)
temperature_moy["country"] = countries
temperature_moy = temperature_moy.drop(["AverageTemperatureUncertainty"],axis=1)
temperature_moy.to_csv('2013.csv', index=False)
temperature_moy
# Out:
#                                    AverageTemperature  \
# Country
# Afghanistan                                 16.533625
# Africa                                      25.208750
# Albania                                     14.993875
# Algeria                                     25.121500
# American Samoa                              27.517250
# Andorra                                     12.307875
# Angola                                      22.507875
# Anguilla                                    27.363000
# Antigua And Barbuda                         27.249625
# Argentina                                   14.457125
# Armenia                                     11.343750
# Aruba                                       28.541250
# Asia                                        10.047375
# Australia                                   22.142875
# Austria                                      8.055125
# Azerbaijan                                  14.173875
# Bahamas                                     26.011667
# Bahrain                                     27.925375
# Baker Island                                26.431750
# Bangladesh                                  25.967500
# Barbados                                    27.251125
# Belarus                                      8.266500
# Belgium                                     10.060125
# Belize                                      26.213333
# Benin                                       28.160625
# Bhutan                                      13.331375
# Bolivia                                     20.640875
# Bonaire, Saint Eustatius And Saba           27.919625
# Bosnia And Herzegovina                      12.879500
# Botswana                                    21.825750
# ...                                               ...
# Sweden                                       4.199750
# Switzerland                                  8.177500
# Syria                                       20.021125
# Taiwan                                      23.015000
# Tajikistan                                   6.562625
# Tanzania                                    22.772750
# Thailand                                    27.864875
# Timor Leste                                 26.312500
# Togo                                        27.718000
# Tonga                                       24.285875
# Trinidad And Tobago                         27.086625
# Tunisia                                     21.887125
# Turkey                                      14.026625
# Turkmenistan                                18.613500
# Turks And Caicas Islands                    27.440556
# Uganda                                      24.024625
# Ukraine                                     10.913500
# United Arab Emirates                        29.370625
# United Kingdom                               8.997500
# United Kingdom (Europe)                      9.108250
# United States                               11.297111
# Uruguay                                     16.754375
# Uzbekistan                                  16.188250
# Venezuela                                   25.912875
# Vietnam                                     25.232125
# Virgin Islands                              27.312333
# Western Sahara                              23.744250
# Yemen                                       28.129750
# Zambia                                      21.196000
# Zimbabwe                                    20.710750
#
#                                                              country
# Country
# Afghanistan                                              Afghanistan
# Africa                                                        Africa
# Albania                                                      Albania
# Algeria                                                      Algeria
# American Samoa                                        American Samoa
# Andorra                                                      Andorra
# Angola                                                        Angola
# Anguilla                                                    Anguilla
# Antigua And Barbuda                              Antigua And Barbuda
# Argentina                                                  Argentina
# Armenia                                                      Armenia
# Aruba                                                          Aruba
# Asia                                                            Asia
# Australia                                                  Australia
# Austria                                                      Austria
# Azerbaijan                                                Azerbaijan
# Bahamas                                                      Bahamas
# Bahrain                                                      Bahrain
# Baker Island                                            Baker Island
# Bangladesh                                                Bangladesh
# Barbados                                                    Barbados
# Belarus                                                      Belarus
# Belgium                                                      Belgium
# Belize                                                        Belize
# Benin                                                          Benin
# Bhutan                                                        Bhutan
# Bolivia                                                      Bolivia
# Bonaire, Saint Eustatius And Saba  Bonaire, Saint Eustatius And Saba
# Bosnia And Herzegovina                        Bosnia And Herzegovina
# Botswana                                                    Botswana
# ...                                                              ...
# Sweden                                                        Sweden
# Switzerland                                              Switzerland
# Syria                                                          Syria
# Taiwan                                                        Taiwan
# Tajikistan                                                Tajikistan
# Tanzania                                                    Tanzania
# Thailand                                                    Thailand
# Timor Leste                                              Timor Leste
# Togo                                                            Togo
# Tonga                                                          Tonga
# Trinidad And Tobago                              Trinidad And Tobago
# Tunisia                                                      Tunisia
# Turkey                                                        Turkey
# Turkmenistan                                            Turkmenistan
# Turks And Caicas Islands                    Turks And Caicas Islands
# Uganda                                                        Uganda
# Ukraine                                                      Ukraine
# United Arab Emirates                            United Arab Emirates
# United Kingdom                               United Kingdom (Europe)
# United Kingdom (Europe)                               United Kingdom
# United States                                          United States
# Uruguay                                                      Uruguay
# Uzbekistan                                                Uzbekistan
# Venezuela                                                  Venezuela
# Vietnam                                                      Vietnam
# Virgin Islands                                        Virgin Islands
# Western Sahara                                        Western Sahara
# Yemen                                                          Yemen
# Zambia                                                        Zambia
# Zimbabwe                                                    Zimbabwe
#
# [241 rows x 2 columns]
